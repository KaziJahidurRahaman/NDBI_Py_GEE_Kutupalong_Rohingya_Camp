# %%
# !pip install earthengine-api
# !pip install altair
# !pip install geemap

# %%
# Import the required libraries

import pandas as pd
import altair as alt
import numpy as np
import folium
import ee
import geemap
from tqdm import tqdm

# %% [markdown]
# <p> We are using google earth engine api to pull and analize the data from the google earthengine server. For that, we first need to authenticate the earth engine api with proper google credentials. to know more about the authentication process checkout <a href="https://developers.google.com/earth-engine/apidocs/ee-authenticate"><b>Authenticator</b></a>

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=S1QQKvcwIGkucCPkGXSQHtfKBSEfS1a2_sB7sipmbzQ&tc=XKD2RuG3ul_ck9AUR-P9xM5aME4j1FRh33v_AUcZc7E&cc=qpUAl7YIUYw57Oarmn2CrTtcpNWI5W5jC7WbtX1sJp8>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=S1QQKvcwIGkucCPkGXSQHtfKBSEfS1a2_sB7sipmbzQ&tc=XKD2RuG3ul_ck9AUR-P9xM5aME4j1FRh33v_AUcZc7E&cc=qpUAl7YIUYw57Oarmn2CrTtcpNWI5W5jC7WbtX1sJp8</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AfgeXvt_wGmV5e0u3JfqWgvf9KfgOLrLYnOCTRvL-ySnpg2-cptQEnsthxU
#
# Successfully saved authorization token.

# %% [markdown]
# Now we will define our analysis time frame. We are considering images of 20 years earlier from the current timestamp.

# %%
today = ee.Date(pd.to_datetime('today'))
date_range = ee.DateRange(today.advance(-20, 'years'), today)

# %% [markdown]
# The are of interest is the <a href="https://en.wikipedia.org/wiki/Kutupalong_refugee_camp"><b>Kutupalong Rohingya Camp</b></a>, Cox's Bazar, in Bangladesh.

# %%
aoi_shp_path =  "aoi/Kutupalong-AOI-Polygon-polygon.shp"
aoi = geemap.shp_to_ee(aoi_shp_path)
aoi

# %%
aoi.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {'Name': 'String',
#   'descriptio': 'String',
#   'system:index': 'String',
#   'tessellate': 'Integer'},
#  'features': [{'type': 'Feature',
#    'geometry': {'geodesic': False,
#     'type': 'Polygon',
#     'coordinates': [[[92.12844545199196, 21.17519523146724],
#       [92.12488402839178, 21.2198086869558],
#       [92.1774510964344, 21.21985803329638],
#       [92.17108354208149, 21.17496411425513],
#       [92.12844545199196, 21.17519523146724]]]},
#    'id': '0',
#    'properties': {'Name': 'Kutupalong-AOI-Polygon',
#     'descriptio': '',
#     'tessellate': 1}}]}

# %%
import numpy as np
aoi_geometry = aoi.geometry()
coords = aoi_geometry.getInfo()['coordinates']
mapBoundary = coords[0][1]

coords = np.array(coords[0])
coords
# Out:
# array([[92.12844545, 21.17519523],
#        [92.12488403, 21.21980869],
#        [92.1774511 , 21.21985803],
#        [92.17108354, 21.17496411],
#        [92.12844545, 21.17519523]])

# %%
landsat =  ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA')\
.filterMetadata('WRS_PATH','equals',136).filterMetadata('WRS_ROW', 'equals',45)\
.filterDate(date_range)\
.filter(ee.Filter.lt('CLOUD_COVER', 20))
print("Total Image Downloaded: ",landsat.size().getInfo()) #gets the total number of images
# Out:
# Total Image Downloaded:  76

# %%
test_image = landsat.first()
test_image = test_image.clip(aoi)

# %%
test_image.getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B8',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [15321, 15621],
#    'crs': 'EPSG:32646',
#    'crs_transform': [15, 0, 239092.5, 0, -15, 2514007.5]},
#   {'id': 'B9',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B10',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'B11',
#    'data_type': {'type': 'PixelType', 'precision': 'float'},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]},
#   {'id': 'BQA',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7811],
#    'crs': 'EPSG:32646',
#    'crs_transform': [30, 0, 239085, 0, -30, 2514015]}],
#  'version': 1655337549451297,
#  'id': 'LANDSAT/LC08/C01/T1_TOA/LC08_136045_20130912',
#  'properties': {'RADIANCE_MULT_BAND_5': 0.006035900209099054,
#   'RADIANCE_MULT_BAND_6': 0.0015011000214144588,
#   'RADIANCE_MULT_BAND_3': 0.01169699989259243,
#   'RADIANCE_MULT_BAND_4': 0.009863399900496006,
#   'RADIANCE_MULT_BAND_1': 0.012396000325679779,
#   'RADIANCE_MULT_BAND_2': 0.01269300002604723,
#   'K2_CONSTANT_BAND_11': 1201.1441650390625,
#   'K2_CONSTANT_BAND_10': 1321.078857421875,
#   'REFLECTIVE_SAMPLES': 7661,
#   'SUN_AZIMUTH': 125.99512481689453,
#   'CPF_NAME': 'LC08CPF_20130701_20130919_01.01',
#   'DATE_ACQUIRED': '2013-09-12',
#   'ELLIPSOID': 'WGS84',
#   'google:registration_offset_x': -426.4895935058594,
#   'google:registration_offset_y': -296.8622741699219,
#   'STATION_ID': 'LGN',
#   'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#   'ORIENTATION': 'NORTH_UP',
#   'WRS_ROW': 45,
#   'RADIANCE_MULT_BAND_9': 0.0023590000346302986,
#   'TARGET_WRS_ROW': 45,
#   'RADIANCE_MULT_BAND_7': 0.0005059399991296232,
#   'RADIANCE_MULT_BAND_8': 0.011163000017404556,
#   'IMAGE_QUALITY_TIRS': 9,
#   'TRUNCATION_OLI': 'UPPER',
#   'CLOUD_COVER': 11.760000228881836,
#   'GEOMETRIC_RMSE_VERIFY': 5.934000015258789,
#   'COLLECTION_CATEGORY': 'T1',
#   'GRID_CELL_SIZE_REFLECTIVE': 30,
#   'CLOUD_COVER_LAND': 13.9399995803833,
#   'GEOMETRIC_RMSE_MODEL': 8.364999771118164,
#   'COLLECTION_NUMBER': 1,
#   'IMAGE_QUALITY_OLI': 9,
#   'LANDSAT_SCENE_ID': 'LC81360452013255LGN01',
#   'WRS_PATH': 136,
#   'google:registration_count': 83,
#   'PANCHROMATIC_SAMPLES': 15321,
#   'PANCHROMATIC_LINES': 15621,
#   'GEOMETRIC_RMSE_MODEL_Y': 6.051000118255615,
#   'REFLECTIVE_LINES': 7811,
#   'TIRS_STRAY_LIGHT_CORRECTION_SOURCE': 'TIRS',
#   'GEOMETRIC_RMSE_MODEL_X': 5.775000095367432,
#   'system:asset_size': 1168034452,
#   'system:index': 'LC08_136045_20130912',
#   'REFLECTANCE_ADD_BAND_1': -0.10000000149011612,
#   'REFLECTANCE_ADD_BAND_2': -0.10000000149011612,
#   'DATUM': 'WGS84',
#   'REFLECTANCE_ADD_BAND_3': -0.10000000149011612,
#   'REFLECTANCE_ADD_BAND_4': -0.10000000149011612,
#   'RLUT_FILE_NAME': 'LC08RLUT_20130211_20150302_01_11.h5',
#   'REFLECTANCE_ADD_BAND_5': -0.10000000149011612,
#   'REFLECTANCE_ADD_BAND_6': -0.10000000149011612,
#   'REFLECTANCE_ADD_BAND_7': -0.10000000149011612,
#   'REFLECTANCE_ADD_BAND_8': -0.10000000149011612,
#   'BPF_NAME_TIRS': 'LT8BPF20130912040125_20130912043936.01',
#   'GROUND_CONTROL_POINTS_VERSION': 4,
#   'DATA_TYPE': 'L1TP',
#   'UTM_ZONE': 46,
#   'LANDSAT_PRODUCT_ID': 'LC08_L1TP_136045_20130912_20170502_01_T1',
#   'REFLECTANCE_ADD_BAND_9': -0.10000000149011612,
#   'google:registration_ratio': 0.4689265489578247,
#   'GRID_CELL_SIZE_PANCHROMATIC': 15,
#   'RADIANCE_ADD_BAND_4': -49.316898345947266,
#   'REFLECTANCE_MULT_BAND_7': 1.9999999494757503e-05,
#   'system:time_start': 1378959662280,
#   'RADIANCE_ADD_BAND_5': -30.179479598999023,
#   'REFLECTANCE_MULT_BAND_6': 1.9999999494757503e-05,
#   'RADIANCE_ADD_BAND_6': -7.505360126495361,
#   'REFLECTANCE_MULT_BAND_9': 1.9999999494757503e-05,
#   'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.7.0',
#   'RADIANCE_ADD_BAND_7': -2.529710054397583,
#   'REFLECTANCE_MULT_BAND_8': 1.9999999494757503e-05,
#   'RADIANCE_ADD_BAND_1': -61.978309631347656,
#   'RADIANCE_ADD_BAND_2': -63.4665412902832,
#   'RADIANCE_ADD_BAND_3': -58.48387908935547,
#   'REFLECTANCE_MULT_BAND_1': 1.9999999494757503e-05,
#   'RADIANCE_ADD_BAND_8': -55.81315994262695,
#   'REFLECTANCE_MULT_BAND_3': 1.9999999494757503e-05,
#   'RADIANCE_ADD_BAND_9': -11.794830322265625,
#   'REFLECTANCE_MULT_BAND_2': 1.9999999494757503e-05,
#   'REFLECTANCE_MULT_BAND_5': 1.9999999494757503e-05,
#   'REFLECTANCE_MULT_BAND_4': 1.9999999494757503e-05,
#   'THERMAL_LINES': 7811,
#   'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#   'GRID_CELL_SIZE_THERMAL': 30,
#   'NADIR_OFFNADIR': 'NADIR',
#   'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#   'REQUEST_ID': '0501705013965_00010',
#   'EARTH_SUN_DISTANCE': 1.0064369440078735,
#   'TIRS_SSM_MODEL': 'ACTUAL',
#   'FILE_DATE': 1493724221000,
#   'SCENE_CENTER_TIME': '04:21:02.2792730Z',
#   'SUN_ELEVATION': 62.19953536987305,
#   'BPF_NAME_OLI': 'LO8BPF20130912040519_20130912043843.01',
#   'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#   'ROLL_ANGLE': -0.0010000000474974513,
#   'K1_CONSTANT_BAND_10': 774.8853149414062,
#   'SATURATION_BAND_1': 'N',
#   'SATURATION_BAND_2': 'N',
#   'SATURATION_BAND_3': 'N',
#   'SATURATION_BAND_4': 'N',
#   'SATURATION_BAND_5': 'Y',
#   'MAP_PROJECTION': 'UTM',
#   'SATURATION_BAND_6': 'Y',
#   'SENSOR_ID': 'OLI_TIRS',
#   'SATURATION_BAND_7': 'Y',
#   'K1_CONSTANT_BAND_11': 480.8883056640625,
#   'SATURATION_BAND_8': 'N',
#   'SATURATION_BAND_9': 'N',
#   'TARGET_WRS_PATH': 136,
#   'RADIANCE_MULT_BAND_11': 0.00033420001273043454,
#   'RADIANCE_MULT_BAND_10': 0.00033420001273043454,
#   'GROUND_CONTROL_POINTS_MODEL': 98,
#   'SPACECRAFT_ID': 'LANDSAT_8',
#   'ELEVATION_SOURCE': 'GLS2000',
#   'THERMAL_SAMPLES': 7661,
#   'GROUND_CONTROL_POINTS_VERIFY': 28}}

# %%
# ##### earth-engine drawing method setup
def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
      tiles = map_id_dict['tile_fetcher'].url_format,
      attr = 'Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
      name = name,
      overlay = True,
      control = True
  ).add_to(self)

# configuring earth engine display rendering method in folium
folium.Map.add_ee_layer = add_ee_layer

# visual parameters for the satellite imagery natural colors display
image_params = {
  'bands': ['B4',  'B3',  'B2'],
  'min': 0,
  'max': 0.3,
  'gamma': 1
}

map = folium.Map(location=[coords[:,1].mean(), coords[:,0].mean()], 
                 zoom_start=13, height=400, control_scale=True)
map.add_ee_layer(test_image, image_params, 'LandsatFirst')
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19bb2c1c7368720c89d22a6049198941 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19bb2c1c7368720c89d22a6049198941&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19bb2c1c7368720c89d22a6049198941 = L.map(
#                 &quot;map_19bb2c1c7368720c89d22a6049198941&quot;,
#                 {
#                     center: [21.193004259488358, 92.14606191417832],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_19bb2c1c7368720c89d22a6049198941);
#
#
#
#
#
#             var tile_layer_970af4a9e326f0300434c330c849076a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19bb2c1c7368720c89d22a6049198941);
#
#
#             var tile_layer_6422987cc2b49048b3102acec002694c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/866be4f63f2bba17d743129314b6e60d-740fd460057ec978d57f4b970c96f74e/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19bb2c1c7368720c89d22a6049198941);
#
#
#             var layer_control_9eca57e10b7d0752877eb0b3819d9472 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_970af4a9e326f0300434c330c849076a,
#                 },
#                 overlays :  {
#                     &quot;LandsatFirst&quot; : tile_layer_6422987cc2b49048b3102acec002694c,
#                 },
#             };
#             L.control.layers(
#                 layer_control_9eca57e10b7d0752877eb0b3819d9472.base_layers,
#                 layer_control_9eca57e10b7d0752877eb0b3819d9472.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_19bb2c1c7368720c89d22a6049198941);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# NDBI = (SWIR - NIR) / (SWIR + NIR)

# %%
nir  = test_image.select('B4')
swir = test_image.select('B5')


ndbi = swir.subtract(nir).divide(swir.add(nir)).rename('NDBI')

# %%
ndbi_visParams = {min: -1, max: 1};


map_ndbi = folium.Map(location=[coords[:,1].mean(), coords[:,0].mean()], 
                 zoom_start=13, height=400, control_scale=True)
map_ndbi.add_ee_layer(ndbi, ndbi_visParams, 'NDBI')

map_ndbi.add_child(folium.LayerControl())


map_ndbi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_396ad5aab663d9b1e982fe0557b815fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_396ad5aab663d9b1e982fe0557b815fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_396ad5aab663d9b1e982fe0557b815fd = L.map(
#                 &quot;map_396ad5aab663d9b1e982fe0557b815fd&quot;,
#                 {
#                     center: [21.193004259488358, 92.14606191417832],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_396ad5aab663d9b1e982fe0557b815fd);
#
#
#
#
#
#             var tile_layer_a86b7a65bbfd20f9fb1c34406aa7a80c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_396ad5aab663d9b1e982fe0557b815fd);
#
#
#             var tile_layer_fed1d9c40c4554ce18443f8f4ec7cf90 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/0bfdaff1cad3dd8968915f83527a2272-ce01014ae42691153724775f22038b28/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_396ad5aab663d9b1e982fe0557b815fd);
#
#
#             var layer_control_6320709440229d6fe59902c5ddffe49e = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a86b7a65bbfd20f9fb1c34406aa7a80c,
#                 },
#                 overlays :  {
#                     &quot;NDBI&quot; : tile_layer_fed1d9c40c4554ce18443f8f4ec7cf90,
#                 },
#             };
#             L.control.layers(
#                 layer_control_6320709440229d6fe59902c5ddffe49e.base_layers,
#                 layer_control_6320709440229d6fe59902c5ddffe49e.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_396ad5aab663d9b1e982fe0557b815fd);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# doi.toList(doi.size())
landsat.size()

# %%
def get_ndbi_info(img):
    
    img_date = img.date().getInfo()['value']
    img_sytemindex = img.get('system:index').getInfo()
  
    nir  = img.select('B4')
    swir = img.select('B5')
    
    ndbi = swir.subtract(nir).divide(swir.add(nir)).rename('NDBI')
    
    min_ndbi_val = ndbi.reduceRegion(ee.Reducer.min(), aoi, 30,  crs = 'EPSG:32648', bestEffort = True, maxPixels = 1e9).getInfo()['NDBI']
    max_ndbi_val = ndbi.reduceRegion(ee.Reducer.max(), aoi, 30,  crs = 'EPSG:32648', bestEffort = True, maxPixels = 1e9).getInfo()['NDBI']
    mean_ndbi_val = ndbi.reduceRegion(ee.Reducer.mean(), aoi, 30,  crs = 'EPSG:32648', bestEffort = True, maxPixels = 1e9).getInfo()['NDBI']
    
    img_all_info = {
      'system:index': img_sytemindex,
      'date': img_date,
      'min_ndbi' : min_ndbi_val,
      'max_ndbi' : max_ndbi_val,
      'mean_ndbi' : mean_ndbi_val      
      }

    return img_all_info

# %%
landsat

# %%
landsat_list = landsat.toList(landsat.size())
landsat_list_size = landsat_list.size().getInfo()

import pandas as pd
df = pd.DataFrame(columns=['SystemIndex', 'Millis', 'MinNDBI', 'MaxNDBI', 'MeanNDBI'])

for i in tqdm(range(landsat_list_size)):
    image = ee.Image(landsat_list.get(i))
    image_info = get_ndbi_info(image)
#     print(image_info)
    df = df.append({'SystemIndex': image_info['system:index'], 
                    'Millis':  image_info['date'], 
                    'MinNDBI': image_info['min_ndbi'], 
                    'MaxNDBI': image_info['max_ndbi'], 
                    'MeanNDBI': image_info['mean_ndbi']}, 
                    ignore_index=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 76/76 [04:54<00:00,  3.88s/it]

# %%
df
# Out:
#              SystemIndex         Millis   MinNDBI   MaxNDBI  MeanNDBI
# 0   LC08_136045_20130912  1378959662280 -0.501476  0.856036  0.691952
# 1   LC08_136045_20131014  1381724454570 -0.293474  0.832426  0.642996
# 2   LC08_136045_20131030  1383106845650 -0.365039  0.849545  0.705365
# 3   LC08_136045_20131201  1385871639720 -0.326832  0.789117  0.608659
# 4   LC08_136045_20131217  1387254032730  -0.41801  0.794675  0.586202
# ..                   ...            ...       ...       ...       ...
# 71  LC08_136045_20210427  1619497117542  0.022426  0.436299     0.156
# 72  LC08_136045_20210529  1622261925631  -0.02558  0.636801  0.238946
# 73  LC08_136045_20211105  1636085967127 -0.142485  0.791913  0.487977
# 74  LC08_136045_20211121  1637468362754 -0.202247  0.766042  0.448745
# 75  LC08_136045_20211223  1640233160866 -0.000838  0.580632  0.321162
#
# [76 rows x 5 columns]

# %%
def add_date_info(df):
  df['Timestamp'] = pd.to_datetime(df['Millis'], unit='ms')
  df['Year'] = pd.DatetimeIndex(df['Timestamp']).year
  df['Month'] = pd.DatetimeIndex(df['Timestamp']).month
  df['Day'] = pd.DatetimeIndex(df['Timestamp']).day
  df['DOY'] = pd.DatetimeIndex(df['Timestamp']).dayofyear
  return df

# %%
df = add_date_info(df).drop(columns=['Millis'])
df
# Out:
#              SystemIndex   MinNDBI   MaxNDBI  MeanNDBI  \
# 0   LC08_136045_20130912 -0.501476  0.856036  0.691952
# 1   LC08_136045_20131014 -0.293474  0.832426  0.642996
# 2   LC08_136045_20131030 -0.365039  0.849545  0.705365
# 3   LC08_136045_20131201 -0.326832  0.789117  0.608659
# 4   LC08_136045_20131217  -0.41801  0.794675  0.586202
# ..                   ...       ...       ...       ...
# 71  LC08_136045_20210427  0.022426  0.436299     0.156
# 72  LC08_136045_20210529  -0.02558  0.636801  0.238946
# 73  LC08_136045_20211105 -0.142485  0.791913  0.487977
# 74  LC08_136045_20211121 -0.202247  0.766042  0.448745
# 75  LC08_136045_20211223 -0.000838  0.580632  0.321162
#
#                  Timestamp  Year  Month  Day  DOY
# 0  2013-09-12 04:21:02.280  2013      9   12  255
# 1  2013-10-14 04:20:54.570  2013     10   14  287
# 2  2013-10-30 04:20:45.650  2013     10   30  303
# 3  2013-12-01 04:20:39.720  2013     12    1  335
# 4  2013-12-17 04:20:32.730  2013     12   17  351
# ..                     ...   ...    ...  ...  ...
# 71 2021-04-27 04:18:37.542  2021      4   27  117
# 72 2021-05-29 04:18:45.631  2021      5   29  149
# 73 2021-11-05 04:19:27.127  2021     11    5  309
# 74 2021-11-21 04:19:22.754  2021     11   21  325
# 75 2021-12-23 04:19:20.866  2021     12   23  357
#
# [76 rows x 9 columns]

# %%
alt.Chart(df).transform_fold(
    ['MinNDBI', 'MaxNDBI', 'MeanNDBI'],
    as_=['NDBI_Type', 'Value']
).mark_line().encode(
    x='Timestamp:T',
    y='Value:Q',
    color='NDBI_Type:N'
)
# Out:
# alt.Chart(...)
